# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
veri=np.random.seed(42)
import os
path = r"C:\Users\muhlis\OneDrive\Masaüstü\Yeni klasör\universite_notlari.csv"
if not os.path.exists(path):
    raise FileNotFoundError(f"Dosya bulunamadı: {path}")
veri = pd.read_csv(path)
print(veri.head())
# Out:
#    Ogrenci_ID      Ad  Matematik  Fizik  Kimya
# 0           1     Ali         85     78     80
# 1           2    Ayse         90     88     85
# 2           3  Mehmet         70     65     72
# 3           4  Zeynep         95     92     90
# 4           5     Can         60     55     58

# %%
veri.describe()
veri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Ogrenci_ID  5 non-null      int64
#  1   Ad          5 non-null      object
#  2   Matematik   5 non-null      int64
#  3   Fizik       5 non-null      int64
#  4   Kimya       5 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 332.0+ bytes

# %%
veri["Ad"].head()
# Out:
# 0       Ali
# 1      Ayse
# 2    Mehmet
# 3    Zeynep
# 4       Can
# Name: Ad, dtype: object

# %%
veri["Ad"].value_counts()
# Out:
# Ad
# Ali       1
# Ayse      1
# Mehmet    1
# Zeynep    1
# Can       1
# Name: count, dtype: int64

# %%
veri[["Ogrenci_ID","Ad"]].head()
# Out:
#    Ogrenci_ID      Ad
# 0           1     Ali
# 1           2    Ayse
# 2           3  Mehmet
# 3           4  Zeynep
# 4           5     Can

# %%
veri[["Ogrenci_ID","Matematik"]].corr()
# Out:
#             Ogrenci_ID  Matematik
# Ogrenci_ID    1.000000  -0.488094
# Matematik    -0.488094   1.000000

# %%
veri.groupby("Ad").mean()
veri.groupby("Ad").sum()
veri.groupby("Ad").std()
veri.groupby("Ad").max()
veri.groupby("Ad").min()
# Out:
#         Ogrenci_ID  Matematik  Fizik  Kimya
# Ad
# Ali              1         85     78     80
# Ayse             2         90     88     85
# Can              5         60     55     58
# Mehmet           3         70     65     72
# Zeynep           4         95     92     90

# %%
veri["Ogrenci_ID"].value_counts().sort_values(ascending=True)
# Out:
# Ogrenci_ID
# 1    1
# 2    1
# 3    1
# 4    1
# 5    1
# Name: count, dtype: int64

# %%
veri["Ad"].value_counts().sort_values
# Out:
# <bound method Series.sort_values of Ad
# Ali       1
# Ayse      1
# Mehmet    1
# Zeynep    1
# Can       1
# Name: count, dtype: int64>

# %%
veri["Matematik"].value_counts().sort_values(ascending=True)
# Out:
# Matematik
# 85    1
# 90    1
# 70    1
# 95    1
# 60    1
# Name: count, dtype: int64

# %%
veri["Matematik"].value_counts().median()
veri["Fizik"].value_counts().median()
veri["Kimya"].value_counts().median()

print(f'Matematik Medyanı: {veri["Matematik"].median()}')
print(f'Fizik Medyanı: {veri["Fizik"].median()}')
print(f'Kimya Medyanı: {veri["Kimya"].median()}')
# Out:
# Matematik Medyanı: 85.0
# Fizik Medyanı: 78.0
# Kimya Medyanı: 80.0

# %%
veri["Ad"].value_counts().plot(kind="bar")
plt.show()
