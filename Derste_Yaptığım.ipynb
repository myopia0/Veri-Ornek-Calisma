# %% [markdown]
# <a href="https://colab.research.google.com/github/myopia0/Veri-Ornek-Calisma/blob/main/Derste_Yapt%C4%B1%C4%9F%C4%B1m.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
veri=np.random.seed(42)
veri=pd.read_csv("/content/anket_verisi1.csv")
veri.head()
# Out:
#    ogrenci_id cinsiyet     bolum  calisma_suresi  memnuniyet
# 0           1    Kadın  Elektrik               6           3
# 1           2    Erkek    Makine               6           3
# 2           3    Kadın    Makine               0           1
# 3           4    Kadın  Endüstri               3           5
# 4           5    Kadın    Makine               4           4

# %%
veri.describe
veri.dtypes
# Out:
# ogrenci_id         int64
# cinsiyet          object
# bolum             object
# calisma_suresi     int64
# memnuniyet         int64
# dtype: object

# %%
veri["cinsiyet"].value_counts()
# Out:
# cinsiyet
# Erkek    56
# Kadın    44
# Name: count, dtype: int64

# %%
veri[["cinsiyet","bolum"]].value_counts()
# Out:
# cinsiyet  bolum
# Erkek     Elektrik      20
# Kadın     Bilgisayar    15
# Erkek     Endüstri      13
#           Makine        12
#           Bilgisayar    11
# Kadın     Endüstri      11
#           Elektrik      10
#           Makine         8
# Name: count, dtype: int64

# %%
veri[["cinsiyet","bolum","calisma_suresi","memnuniyet"]].value_counts()
# Out:
# cinsiyet  bolum       calisma_suresi  memnuniyet
# Erkek     Elektrik    5               4             3
# Kadın     Makine      4               4             3
# Erkek     Elektrik    2               4             2
#                       1               3             2
# Kadın     Bilgisayar  0               3             2
#                                                    ..
#           Endüstri    6               5             1
#           Makine      0               3             1
#                       5               2             1
#                                       3             1
#                       6               1             1
# Name: count, Length: 83, dtype: int64

# %%
veri[["calisma_suresi","memnuniyet"]].value_counts(normalize=True)*100
# Out:
# calisma_suresi  memnuniyet
# 0               1             6.0
# 4               4             6.0
# 0               3             5.0
# 6               4             5.0
# 5               1             5.0
# 3               4             5.0
# 1               3             5.0
# 0               5             4.0
# 3               1             4.0
#                 3             4.0
# 5               3             4.0
# 3               2             4.0
# 2               3             4.0
# 1               1             3.0
# 2               2             3.0
# 6               1             3.0
# 5               4             3.0
#                 5             3.0
# 4               1             3.0
#                 3             3.0
# 0               4             2.0
#                 2             2.0
# 1               4             2.0
# 6               5             2.0
# 2               4             2.0
#                 1             2.0
# ...

# %%
print(f"medyan calisma suresi={veri['calisma_suresi'].median()}")
print(f"std calisma suresi= {veri['calisma_suresi'].std()}")
print(f"variance calisma suresi= {veri['calisma_suresi'].var()}")
# Out:
# medyan calisma suresi=3.0
# std calisma suresi= 2.0489958121928504
# variance calisma suresi= 4.1983838383838386

# %%
veri["memnuniyet"].value_counts().sort_values()
# Out:
# memnuniyet
# 5    11
# 2    11
# 4    25
# 1    26
# 3    27
# Name: count, dtype: int64

# %%
veri["memnuniyet"].value_counts().median()
# Out:
# 25.0

# %%
veri[['calisma_suresi','memnuniyet']].corr()
# Out:
#                 calisma_suresi  memnuniyet
# calisma_suresi        1.000000    0.087541
# memnuniyet            0.087541    1.000000

# %%
veri.groupby("bolum")["cinsiyet"].value_counts()
# Out:
# bolum       cinsiyet
# Bilgisayar  Kadın       15
#             Erkek       11
# Elektrik    Erkek       20
#             Kadın       10
# Endüstri    Erkek       13
#             Kadın       11
# Makine      Erkek       12
#             Kadın        8
# Name: count, dtype: int64

# %%
veri.groupby("calisma_suresi")["memnuniyet"].value_counts()
# Out:
# calisma_suresi  memnuniyet
# 0               1             6
#                 3             5
#                 5             4
#                 2             2
#                 4             2
# 1               3             5
#                 1             3
#                 4             2
# 2               3             4
#                 2             3
#                 1             2
#                 4             2
#                 5             1
# 3               4             5
#                 1             4
#                 2             4
#                 3             4
#                 5             1
# 4               4             6
#                 1             3
#                 3             3
# 5               1             5
#                 3             4
#                 4             3
#                 5             3
#                 2             1
# 6               4             5
#                 1             3
# ...

# %%
import matplotlib.pyplot as plt

# %%
veri["bolum"].value_counts().plot(kind="bar")

plt.show()
